# %%
# !git clone https://github.com/takhahashi/conf.git
# %cd 'conf'
# Out:
# Cloning into 'conf'...
# remote: Enumerating objects: 706, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 706 (delta 44), reused 52 (delta 21), pack-reused 629 (from 1)
# Receiving objects: 100% (706/706), 87.36 KiB | 648.00 KiB/s, done.
# Resolving deltas: 100% (448/448), done.
# /content/conf

# %%
# !pip install hydra-core --upgrade
# !pip install datasets
# !pip install transformers
# !pip install orjson
# !pip install wget
# !pip install pytreebank
# !pip install accelerate
# !pip install -U transformers
# !pip install optuna
# !pip install fugashi
# !pip install unidic_lite
# !pip install ipadic
# !pip install gpytorch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=4457dc632d14f69b0dc36c2d7eb918d32f9eac7c9d5faacf543aae9c1694c1ef
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 理研のデータセット

# %%
#@title Y14_1-2_1_3
# !python train.py -m data=riken data.question_id_pref='Y14' data.question_id_suff='1-2_1_3' data.score_id='score' data.fold=0 model.model_type='gaussianregression' model.id=0 model.model_name_or_path='tohoku-nlp/bert-base-japanese-v3' training.num_train_epochs=1 training.output_dir='/content/gaussianregression_bert/${data.question_id_pref}_${data.question_id_suff}/fold${data.fold}/id${model.id}' training.wandb_project='test' training.wandb_runname="test"
# Out:
# 2025-03-22 09:02:19.087422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742634139.108508    2095 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742634139.115001    2095 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-22 09:02:19.137315: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # ASAPデータセット

# %%
#@title prompt_1
# !python train.py -m data=asap data.prompt_id=1 data.fold=0 model.model_type='gaussianregression' model.id=0 model.model_name_or_path='bert-base-uncased' training.num_train_epochs=1 training.output_dir='/content/gaussianregression_bert/prompt_${data.prompt_id}/fold${data.fold}' training.wandb_project='test' training.wandb_runname="test"
# Out:
# 2025-03-22 09:04:52.018522: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742634292.041413    2803 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742634292.048259    2803 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-22 09:04:52.070836: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
